# %%
#memxct multinode scaling (figure 11) (demo data, but we will need 4 of these)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Data
#fixed
df=pd.DataFrame({'x': [1,2,4], #nodes
                 'Total': [3.1508387,4.2112689,6.465829], 
                 'Ap': [2.03283229,1.89022054,2.5159455], 
                 'C': [0.07942261,0.09407656,0.16610658], 
                 'R': [0.58244757,1.30022732,2.07288389] })

# multiple line plot
plt.plot( 'x', 'Total', data=df, marker='o', markerfacecolor='blue', markersize=12, color='blue', linewidth=4)
plt.plot( 'x', 'Ap', data=df, marker='o', markerfacecolor='olive', markersize=12, color='olive', linewidth=4)
plt.plot( 'x', 'C', data=df, marker='o', markerfacecolor='red', markersize=12, color='red', linewidth=4)
plt.plot( 'x', 'R', data=df, marker='o', markerfacecolor='green', markersize=12, color='green', linewidth=4)

plt.title("Strong Scaling (CPU, CDS1)")
plt.xlabel("Number of nodes")
#plt.ylim(ymin=0)
plt.yscale('log')
plt.ylabel("Solution time (s)")
plt.legend(loc='lower right',bbox_to_anchor=(1.05, 1))
plt.xscale('log')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: Second argument 'C' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: Second argument 'R' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.

# %%
#memxct multinode scaling (figure 11) (demo data, but we will need 4 of these)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Data
#fixed
df=pd.DataFrame({'x': [1,2,4], #nodes
                 'Total': [4.6517421,6.0862695,6.9625562], 
                 'Ap': [3.3846098,2.91945726,2.82089182], 
                 'C': [0.08752206,0.08792785,0.14718366], 
                 'R': [0.47724621,1.41479032,2.0602555] })

# multiple line plot
plt.plot( 'x', 'Total', data=df, marker='o', markerfacecolor='blue', markersize=12, color='blue', linewidth=4)
plt.plot( 'x', 'Ap', data=df, marker='o', markerfacecolor='olive', markersize=12, color='olive', linewidth=4)
plt.plot( 'x', 'C', data=df, marker='o', markerfacecolor='red', markersize=12, color='red', linewidth=4)
plt.plot( 'x', 'R', data=df, marker='o', markerfacecolor='green', markersize=12, color='green', linewidth=4)

plt.title("Strong Scaling (CPU, CDS2)")
plt.xlabel("Number of nodes")
#plt.ylim(ymin=0)
plt.yscale('log')
plt.ylabel("Solution time (s)")
plt.legend(loc='lower right',bbox_to_anchor=(1.05, 1))
plt.xscale('log')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: Second argument 'C' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: Second argument 'R' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.

# %%
#memxct multinode scaling (figure 11) (demo data, but we will need 4 of these)
#fixed
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Data
#twonode=
df=pd.DataFrame({'x': [1,2,4], #nodes
                 'Total': [0.25196012,0.16516145,0.12832588], 
                 'Ap': [0.15025837,0.07743975,0.04003738], 
                 'C': [0.03022211,0.04632596,0.06086291], 
                 'R': [0.01103263,0.00679992,0.00646057] })

# multiple line plot
plt.plot( 'x', 'Total', data=df, marker='o', markerfacecolor='blue', markersize=12, color='blue', linewidth=4)
plt.plot( 'x', 'Ap', data=df, marker='o', markerfacecolor='olive', markersize=12, color='olive', linewidth=4)
plt.plot( 'x', 'C', data=df, marker='o', markerfacecolor='red', markersize=12, color='red', linewidth=4)
plt.plot( 'x', 'R', data=df, marker='o', markerfacecolor='green', markersize=12, color='green', linewidth=4)

plt.title("Strong Scaling (GPU, CDS1)")
plt.xlabel("Number of nodes")
#plt.ylim(ymin=0)
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='lower right',bbox_to_anchor=(1.05, 1))
plt.ylabel("Solution time (s)")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: Second argument 'C' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: Second argument 'R' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
# Text(0, 0.5, 'Solution time (s)')

# %%
#memxct multinode scaling (figure 11) (demo data, but we will need 4 of these)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Data
#fixed
df=pd.DataFrame({'x': [1,2,4], #nodes
                 'Total': [0.4810447,0.28003876,0.18592548], 
                 'Ap': [0.3169235,0.16121793,0.07443869], 
                 'C': [0.0299209,0.04620521,0.06106016], 
                 'R': [0.01106155,0.00667414,0.00628527] })

# multiple line plot
plt.plot( 'x', 'Total', data=df, marker='o', markerfacecolor='blue', markersize=12, color='blue', linewidth=4)
plt.plot( 'x', 'Ap', data=df, marker='o', markerfacecolor='olive', markersize=12, color='olive', linewidth=4)
plt.plot( 'x', 'C', data=df, marker='o', markerfacecolor='red', markersize=12, color='red', linewidth=4)
plt.plot( 'x', 'R', data=df, marker='o', markerfacecolor='green', markersize=12, color='green', linewidth=4)

plt.title("Strong Scaling (GPU, CDS2)")
plt.xlabel("Number of nodes")
#plt.ylim(ymin=0)
plt.yscale('log')
plt.xscale('log')
plt.ylabel("Solution time (s)")
plt.legend(loc='lower right',bbox_to_anchor=(1.05, 1))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: Second argument 'C' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: Second argument 'R' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
