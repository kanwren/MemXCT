# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('CDS1', 'CDS2', 'CDS3')
y_pos = np.arange(len(objects))
performance = [79.972216,83.987296,67.237129]
plt.figure(figsize=(3.5,3.5))
plt.bar(y_pos, performance, align='center', alpha=0.5)
for a,b in zip(y_pos, performance):
    plt.text(a-0.4, b+0.04, str(b))
plt.xticks(y_pos, objects)
plt.ylabel('GB/s')
plt.xlabel('Dataset')
plt.title('Single-node CPU Memory Bandwidth Utilization')

plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('CDS1', 'CDS2')
y_pos = np.arange(len(objects))
performance = [825.0662181,827.7900323]
plt.figure(figsize=(3.5,3.5))
for a,b in zip(y_pos, performance):
    plt.text(a-0.3, b+0.04, str(b))
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('GB/s')
plt.xlabel('Dataset')
plt.title('Single-node GPU Memory Bandwidth Utilization')

plt.show()
